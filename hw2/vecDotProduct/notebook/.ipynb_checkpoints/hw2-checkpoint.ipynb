# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [2, 4, 8, 16, 32, 64, 128, 256, 512]
total_time = [398.956482, 230.442108, 147.089493, 101.582596, 78.679008, 67.385117, 68.799171, 58.835869, 58.930176]
plt.plot(x, total_time)
plt.xlabel('Block size')
plt.xscale('log')
plt.ylabel('Elapsed time(ms)')
plt.title('GPU Total time fixing grid size=32')
plt.savefig('gpu_total_time_fixing_grid_size.png', dpi=300)
plt.show()

# %%
x = [2, 4, 8, 16, 32, 64, 128, 256, 512]
total_time = [398.832764, 231.020996, 146.677505, 101.716064, 78.679008, 68.067039, 68.335007, 59.072803, 60.990364]
plt.plot(x, total_time)
plt.xlabel('Grid size')
plt.xscale("log")
plt.ylabel('Elapsed time(ms)')
plt.title('GPU Total time fixing block size=32 with x in log scale')
plt.savefig('gpu_total_time_fixing_block_size.png', dpi=300)
plt.show()
