# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# CPU simple sampling Processing time with different N
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
process_time = [0.001344, 0.001344, 0.001792, 0.003072, 0.005472, 0.009600, 0.019072, 0.037440, 0.074048, 0.147264, 0.295776]
plt.plot(x, process_time)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('Elapsed time(ms)')
plt.title('CPU simple sampling Processing time with different N')
plt.savefig('cpu_ss.png', dpi=300)
plt.show()

# %%
# CPU importance sampling with metropolis algorithm Processing time with different N
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
process_time = [0.038848, 0.065024, 0.119296, 0.223008, 0.444416, 0.869856, 1.720576, 3.415840, 6.898816, 13.743456, 28.834080]
plt.plot(x, process_time)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('Elapsed time(ms)')
plt.title('CPU importance sampling with metropolis algorithm Processing time\n with different N')
plt.savefig('cpu_mis.png', dpi=300)
plt.show()

# %%
# GPU simple sampling Processing time using 1 GPU with different N fixing block size=16
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
process_time = [0.022208, 0.022272, 0.021728, 0.022688, 0.023232, 0.025344, 0.028416, 0.034272, 0.046272, 0.068320, 0.108416]
plt.plot(x, process_time)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('Elapsed time(ms)')
plt.title('GPU simple sampling Processing time using 1 GPU\n with different N fixing block size=16')
plt.savefig('1gpu_ss.png', dpi=300)
plt.show()

# %%
# GPU simple sampling Processing time using 2 GPU with different N fixing block size=16
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
process_time = [0.018880, 0.018464, 0.020448, 0.019744, 0.018720, 0.025376, 0.022944, 0.026880, 0.033184, 0.042240, 0.066176]
plt.plot(x, process_time)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('Elapsed time(ms)')
plt.title('GPU simple sampling Processing time using 2 GPU\n with different N fixing block size=16')
plt.savefig('2gpu_ss.png', dpi=300)
plt.show()

# %%
# Simple sampling monte carlo simulation the function value mean with different N
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
mean = [0.233897, 0.239620, 0.240755, 0.242906, 0.244939, 0.245690, 0.244112, 0.243196, 0.242966, 0.242658, 0.242790]
plt.plot(x, mean)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('function value mean')
plt.title('Simple sampling monte carlo simulation the function value mean\n with different N')
plt.savefig('ss_mean.png', dpi=300)
plt.show()

# %%
# Importance sampling with metropolis algorithm monte carlo simulation the function value mean with different N
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
mean = [0.234275, 0.239984, 0.241447, 0.242957, 0.245007, 0.245819, 0.244248, 0.243324, 0.243045, 0.242742, 0.242866]
plt.plot(x, mean)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('function value mean')
plt.title('Importance sampling with metropolis algorithm monte carlo simulation\n the function value mean with different N')
plt.savefig('mis_mean.png', dpi=300)
plt.show()

# %%
# Simple sampling monte carlo simulation the function value standard deviation with different N
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
std = [0.006505, 0.004728, 0.003438, 0.002588, 0.001881, 0.001370, 0.000934, 0.000651, 0.000458, 0.000321, 0.000228]
plt.plot(x, std)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('function value standard deviation')
plt.title('Simple sampling monte carlo simulation\n the function value standard deviation with different N')
plt.savefig('ss_std.png', dpi=300)
plt.show()

# %%
# Importance sampling with metropolis algorithm monte carlo simulation the function value standard deviation with different N
x = [64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536]
std = [0.006461, 0.004698, 0.003435, 0.002577, 0.001873, 0.001368, 0.000932, 0.000649, 0.000456, 0.000320, 0.000227]
plt.plot(x, std)
plt.xscale('log')
plt.xlabel('Sample point amount(log)')
plt.ylabel('function value standard deviation')
plt.title('Importance sampling with metropolis algorithm monte carlo simulation\n the function value standard deviation with different N')
plt.savefig('mis_std.png', dpi=300)
plt.show()

# %%
# GPU simple sampling Processing time using 1 GPU with different block size fixing N=16
x = [2, 4, 8, 16, 32, 64, 128, 256, 512]
process_time = [0.306368, 0.190048, 0.129152, 0.108416, 0.113568, 0.114752, 0.123136, 0.110496, 0.110496]
plt.plot(x, process_time)
plt.xscale('log')
plt.xlabel('block size(log)')
plt.ylabel('Elapsed time(ms)')
plt.title('GPU simple sampling Processing time using 1 GPU\n with different block size fixing N=16')
plt.savefig('1gpu_ss_pt.png', dpi=300)
plt.show()

# %%
# GPU simple sampling Processing time using 2 GPU with different block size fixing N=16
x = [2, 4, 8, 16, 32, 64, 128, 256, 512]
process_time = [0.149504, 0.103616, 0.074816, 0.066176, 0.065824, 0.077056, 0.056000, 0.053824, 0.071808]
plt.plot(x, process_time)
plt.xscale('log')
plt.xlabel('block size(log)')
plt.ylabel('Elapsed time(ms)')
plt.title('GPU simple sampling Processing time using 2 GPU\n with different block size fixing N=16')
plt.savefig('2gpu_ss_pt.png', dpi=300)
plt.show()
